# %%
import pandas as pd
from plotter import PlotDrawer
from plotter import calculate_statistics

# %%
data = pd.read_json('deviation.json')
plot_drawer = PlotDrawer(data)

# %%
paths = plot_drawer.draw_plots()

# %%
statistics = calculate_statistics(data)
print(statistics)
# Out:
# {'rb_corners': {'Mean Deviation': 4.307349665924276, 'Max Deviation': 10, 'Min Deviation': 4}, 'mean': {'Mean Deviation': 12.89532038162962, 'Max Deviation': 121.3010550187, 'Min Deviation': 0.1929730646}, 'max': {'Mean Deviation': 25.448010949459093, 'Max Deviation': 179.1654830868, 'Min Deviation': 0.3238863392}, 'min': {'Mean Deviation': 2.920387577018263, 'Max Deviation': 81.7644826566, 'Min Deviation': 0.0074561959}, 'floor_mean': {'Mean Deviation': 11.022442887027394, 'Max Deviation': 121.2440830169, 'Min Deviation': 0.13468571440000002}, 'floor_max': {'Mean Deviation': 20.40549885612732, 'Max Deviation': 177.961811244, 'Min Deviation': 0.1780586586}, 'floor_min': {'Mean Deviation': 3.146245541675204, 'Max Deviation': 81.7915047513, 'Min Deviation': 0.0074561959}, 'ceiling_mean': {'Mean Deviation': 14.768197876232591, 'Max Deviation': 157.3874736234, 'Min Deviation': 0.12316877700000001}, 'ceiling_max': {'Mean Deviation': 24.848019542889237, 'Max Deviation': 179.1654830868, 'Mi
# ...
